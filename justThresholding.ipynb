# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('porsche_gt3.jpg',cv.IMREAD_GRAYSCALE)
img = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,\
            cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(4,1,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
plt.imshow(th1,'gray')

# %%
plt.imshow(th2,'gray')

# %%
plt.imshow(th3,'gray')

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('bookpage.jpg',cv.IMREAD_GRAYSCALE)
img = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img,10,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,\
            cv.THRESH_BINARY,115,1)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv.THRESH_BINARY,115,1)
titles = ['Original Image', 'Global Thresholding (v = 10)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

# %%
plt.imshow(img,'gray')

# %%
plt.imshow(th1,'gray')

# %%
plt.imshow(th2,'gray')

# %%
plt.imshow(th3,'gray')

# %%
for i in range(4):
       cv.imshow(titles[i], images[i])
cv.waitKey(0)
cv.destroyAllWindows()
